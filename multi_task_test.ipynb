# %%
# coding=utf-8
import tensorflow as tf

"""
    中文事件提取 卷积神经网络模型
    john.zhang 2016-12-15
"""
class ace_cnn_model():
    """
    中文事件的发现 由以后候选词和一个触发词是否构成事件 这里是另外一种比较简单的模型
    Relation Classification via Convolutional Deep Neural Network
    这篇文章句子特征用的是每一个词的上下文(包含当前词)作为整体的输入
    """

    def __init__(self, sentence_length=30, event_num_labels=10, role_num_labels=6,windows=3, vocab_size=2048, word_embedding_size=100,
                 pos_embedding_size=10, filter_sizes=[3, 4, 5], filter_num=50, batch_size=2):
        """
        :param sentence_length: 输入句子的长度
        :param event_num_labels: 事件类别数目
        :param role_num_labels: 角色类别数目
        :param windows: 窗口的大小
        :param vocab_size: 训练集中词的数目
        :param word_embedding_size: 词嵌入维数
        :param pos_embedding_size: 位置嵌入维数
        :param trigger_vec: 触发词向量
        :param candidate_vec: 候选词向量
        :param filter_sizes: 滤波器尺寸
        :param filter_num: 滤波器数目
        """
        input_x = tf.placeholder(tf.int32, shape=[batch_size, sentence_length], name="input_x")
        self.input_x = input_x
        # 输入事件标签占位符
        # [batch_size, event_num_labels]
        input_event_y = tf.placeholder(tf.float32, shape=[batch_size, event_num_labels], name="input_event_y")
        self.input_event_y = input_event_y
        # 输入角色标签占位符
        # [batch_size, role_num_labels]
        input_role_y = tf.placeholder(tf.float32, shape=[batch_size, role_num_labels], name="input_role_y")
        self.input_role_y = input_role_y
        
        # 触发词位置向量
        input_t_pos = tf.placeholder(tf.int32, shape=[batch_size, sentence_length], name="input_t_pos")
        self.input_t_pos = input_t_pos
        # 候选词位置向量
        input_c_pos = tf.placeholder(tf.int32, shape=[batch_size, sentence_length], name="input_c_pos")
        self.input_c_pos = input_c_pos

        dropout_keep_prob = tf.placeholder(tf.float32, name="dropout_keep_prob")
        self.dropout_keep_prob = dropout_keep_prob
        
        # 候选词的上下文组成的特征向量
        input_c_context = tf.placeholder(tf.int32, shape=[batch_size, windows], name="input_c_context")
        self.input_c_context = input_c_context
        # 　触发词的上下文组成的特征向量
        input_t_context = tf.placeholder(tf.int32, shape=[batch_size, windows], name="input_t_context")
        self.input_t_context = input_t_context
        # 生成word_embedding 这部分操作相对比较简单 建议用cpu做
        with tf.device('/gpu:0'), tf.name_scope("word_embedding_layer"):
            # 词表 [vocab_size, embedding_size]
            W = tf.Variable(tf.random_normal(shape=[vocab_size, word_embedding_size], mean=0.0, stddev=0.5),
                            name="word_table")
            # 句子特征向量 [batch_size, sentence_length, word_embedding]
            input_word_vec = tf.nn.embedding_lookup(W, input_x)            
            #             print sentence_features
            #             print sentences_features_vec
            #             根据 候选词位置 触发词位置 选取位置向量
            #             在(-sentence_length+1,sentence_length-1)之间一共2*(sentence_length-1)+1个数
            #             look_up 变成合适的正整数
            input_t_pos_t = input_t_pos + (sentence_length - 1)
            Tri_pos = tf.Variable(
                tf.random_normal(shape=[2 * (sentence_length - 1) + 1, pos_embedding_size], mean=0.0, stddev=0.5),
                name="tri_pos_table")
            input_t_pos_vec = tf.nn.embedding_lookup(Tri_pos, input_t_pos_t)
            #             look_up 变成合适的正整数
            input_c_pos_c = input_c_pos + (sentence_length - 1)
            Can_pos = tf.Variable(
                tf.random_normal(shape=[2 * (sentence_length - 1) + 1, pos_embedding_size], mean=0.0, stddev=0.5),
                name="candidate_pos_table")
            input_c_pos_vec = tf.nn.embedding_lookup(Can_pos, input_c_pos_c)
            #             print input_t_pos_vec
            #             print input_c_pos_vec
            # 将距离特征和句子的词特征构成一个整理的特征 作为卷积神经网络的输入
            # [batch_size, sentence_length, word_embedding_size+2*pos_size]
            input_sentence_vec = tf.concat(2, [input_word_vec, input_t_pos_vec, input_c_pos_vec])
            # CNN支持4d输入 因此增加一维向量 用于表示输入通道数目
            intput_sentence_vec_expanded = tf.expand_dims(input_sentence_vec, -1)
            # 词汇特征 lexical leval features
            # 候选词极其上下文 [batch_size, windows, word_embedding_size]
            input_c_context_vec = tf.nn.embedding_lookup(W, input_c_context)
            # 触发词及其上下文 [batch_size, windows, word_embedding_size]
            input_t_context_vec = tf.nn.embedding_lookup(W, input_t_context)
            # print input_sentence_vec
            # print input_c_context_vec
            # print input_t_context_vec
        pooled_outputs = []
        for i, filter_size in enumerate(filter_sizes):
            with tf.device('/gpu:0'), tf.name_scope('conv-maxpool-%s' % filter_size):
                # 这里的句子特征考虑的上当前词
                filter_shape = [filter_size,word_embedding_size + 2 * pos_embedding_size, 1, filter_num]
                W = tf.Variable(tf.truncated_normal(filter_shape, stddev=0.1), name="W")
                b = tf.Variable(tf.constant(0.1, shape=[filter_num]), name="b")
                # 卷积运算
                conv = tf.nn.conv2d(
                    intput_sentence_vec_expanded,
                    W,
                    strides=[1, 1, 1, 1],
                    padding="VALID",
                    name="conv")
                h = tf.nn.relu(tf.nn.bias_add(conv, b), name="relu")
                # 最大化池化 暂时不用动态池化
                pooled = tf.nn.max_pool(
                    h,
                    ksize=[1, sentence_length - filter_size + 1, 1, 1],
                    strides=[1, 1, 1, 1],
                    padding='VALID',
                    name="pool")
                pooled_outputs.append(pooled)
        # 使用到的所有滤波器数目(输出的通道数目)
        num_filters_total = filter_num * len(filter_sizes)
        # 多通道的数据合并
        h_pool = tf.concat(3, pooled_outputs)
        #         print sentences_features_vec_flat
        #         print h_pool
        # 展开送入下一层分类器
        # [batch_size, num_filters_total]
        h_pool_flat = tf.reshape(h_pool, [-1, num_filters_total])
        # print h_pool_flat
        # 候选词极其上下文 触发词极其上下文 [batch_size, windows, word_embedding_size] => [batch_size, windows*word_embedding_size]
        # [batch_size, windows * word_embedding_size]
        input_c_context_vec_flat = tf.reshape(input_c_context_vec, [-1, windows * word_embedding_size])
        # print input_c_context_vec_flat
        # [batch_size, windows * word_embedding_size]
        input_t_context_vec_flat = tf.reshape(input_t_context_vec, [-1, windows * word_embedding_size])
        # print input_t_context_vec_flat
        # print h_pool_flat
        # 原本的论文将lexical leval features和sentence leval features组合
        # 这里采用multi-task的思路 sentence leval features主要应用于事件的发现
        # lexical leval features主要应用于角色的分类
        input_sentence_features = h_pool_flat
        input_lexical_features = tf.concat(1, [input_c_context_vec_flat, input_t_context_vec_flat])
        # 总体的分类器 经过一层dropout 然后再送入softmax
        with tf.device('/gpu:0'), tf.name_scope('dropout'):
            input_sentence_features_dropout = tf.nn.dropout(input_sentence_features, dropout_keep_prob)   
            input_lexical_features_dropout = tf.nn.dropout(input_lexical_features, dropout_keep_prob)
        # 分类器
        with tf.device('/gpu:0'), tf.name_scope('softmax'):
            # num_filters_total是卷积之后的结果 sentence level features
            # 事件类别分类
            W1 = tf.Variable(tf.truncated_normal([num_filters_total, event_num_labels], stddev=0.1), name="W1")
            b1 = tf.Variable(tf.constant(0.1, shape=[event_num_labels]), name="b1")
            xw1 = tf.nn.xw_plus_b(input_sentence_features_dropout, W1, b1)
            scores_event = tf.nn.softmax(xw1, name="scores_event")
            # 2*windows*word_embedding_size是lexical leval features 具体的请看论文当中的详细介绍
            predicts_event = tf.arg_max(scores_event, dimension=1, name="predicts_event")
            self.scores_event = scores_event
            self.predicts_event = predicts_event
            # 角色类别分类
            W2 = tf.Variable(tf.truncated_normal([num_filters_total+2*windows*word_embedding_size+event_num_labels, role_num_labels], stddev=0.1), name="W2")
            b2 = tf.Variable(tf.constant(0.1, shape=[role_num_labels]), name="b2")
             # 将句子特征 候选词和词性以及触发词和词性特征合并用于角色分类
            # input_sentence_features_dropout  sentence features
            # input_lexical_features_dropout  lexical_features
            # scores_event  事件类型分类的输出得分结果
            all_input_fatures = tf.concat(1, [input_lexical_features_dropout, input_sentence_features, scores_event])
            xw2 = tf.nn.xw_plus_b(all_input_fatures, W2, b2)
            scores_role = tf.nn.softmax(xw2, name="scores_role")
            predicts_role = tf.arg_max(scores_role, dimension=1, name="predicts_role")
            self.scores_role = scores_role
            self.predicts_role = predicts_role
        # 模型的代价函数 交叉熵代价函数
        with tf.device('/gpu:0'), tf.name_scope('loss'):
            # 事件的交叉熵代价函数
            entropy_event = tf.nn.softmax_cross_entropy_with_logits(scores_event, input_event_y)
            loss_event = tf.reduce_mean(entropy_event)
            self.loss_event = loss_event
            # 角色的交叉熵代价函数
            entropy_role = tf.nn.softmax_cross_entropy_with_logits(scores_role, input_role_y)
            loss_role = tf.reduce_mean(entropy_role)
            self.loss_role = loss_role
        # 准确度 用于每一次训练时调用
        with tf.device('/gpu:0'), tf.name_scope("accuracy"):
            # 事件的准确度
            correct_event = tf.equal(predicts_event, tf.argmax(input_event_y, 1))
            accuracy_event = tf.reduce_mean(tf.cast(correct_event, "float"), name="accuracy_event")
            self.accuracy_event = accuracy_event
            # 角色的准确度
            correct_role = tf.equal(predicts_role, tf.argmax(input_role_y, 1))
            accuracy_role = tf.reduce_mean(tf.cast(correct_role, "float"), name="accuracy_role")
            self.accuracy_role = accuracy_role

# %%
"""
测试程序 john.zhang 2016-11-28 已验证 程序可以运行
"""
# 数据集配置参数
from DataSets_multi_task import datasets
import time
import datetime
import os
# 文件信息
file = 'datas_ace.txt'
# 生成文件的存储位置
store_path = "ace_data_2016_12_02"
# batch_size的大小
data_batch_size = 20
# 句子的最大长度
max_sequence_length = 25
# 选取的上下文窗口的大小
windows = 3
# 数据集
datas = datasets(file=file, store_path=store_path, batch_size=data_batch_size, max_sequence_length=max_sequence_length,
                 windows=windows)
# 神经网络模型的一些参数
# 模型的最大长度
sentence_length = max_sequence_length
event_num_labels = datas.labels_event_size  # 事件类别数目
role_num_labels = datas.labels_role_size  # 角色类别数目
vocab_size = datas.words_size  # 训练集中词的数目
word_embedding_size = 100  # 词嵌入维数
pos_embedding_size = 10  # 位置嵌入维数
filter_sizes = [3, 4, 5]  # 滤波器大小
filter_num = 100  # 滤波器大小
batch_size = None  # tensorflow中支持为定义长度的标记符合
lr = 1e-3  # 学习率
num_epochs = 1000
with tf.Graph().as_default():
    sess = tf.Session()
    with sess.as_default():
        # 模型文件
        model = ace_cnn_model(sentence_length=sentence_length, 
                              event_num_labels=event_num_labels, 
                              role_num_labels=role_num_labels,
                              vocab_size=vocab_size,
                              word_embedding_size=word_embedding_size,
                              pos_embedding_size=pos_embedding_size, 
                              filter_sizes=filter_sizes, 
                              filter_num=filter_num,
                              batch_size=batch_size)
        # 模型优化算法  两种方式：
        # 方式一 采用两种优化器分别进行
        # 方式二 将两种误差函数合并一起进行
        optimizer_event = tf.train.AdamOptimizer(1e-3)
        grads_and_vars_event = optimizer_event.compute_gradients(model.loss_event) # 事件优化器
        train_op_event = optimizer_event.apply_gradients(grads_and_vars_event)
        
        optimizer_role = tf.train.AdamOptimizer(1e-3)
        grads_and_vars_role = optimizer_role.compute_gradients(model.loss_role)  # 角色优化器
        train_op_role = optimizer_role.apply_gradients(grads_and_vars_role)

        timestamp = str(int(time.time()))
        out_dir = os.path.abspath(os.path.join(os.path.curdir, "ace_cnn_model_02", timestamp))
        print("Writing to {}\n".format(out_dir))
        checkpoint_dir = os.path.abspath(os.path.join(out_dir, "checkpoints"))
        checkpoint_prefix = os.path.join(checkpoint_dir, "model")
        if not os.path.exists(checkpoint_dir):
            os.makedirs(checkpoint_dir)
        saver = tf.train.Saver(tf.all_variables(), max_to_keep=100)  # 最大支持存储100个模型
        # 初始化　变量
        sess.run(tf.initialize_all_variables())
        def train_step(input_x, input_event_y, input_role_y, input_t, input_c, input_t_pos, input_c_pos, dropout_keep_prob
                       ,sentence_features,input_t_context,input_c_context,train_op,loss,accuracy,epoch, stype):
            feed_dict = {
                model.input_x: input_x,  # 句子级别特征
                model.input_event_y: input_event_y,  # 事件类别
                model.input_role_y: input_role_y,  # 角色类别
                # model.input_t:input_t, # 触发词
                # model.input_c:input_c, # 候选词
                model.input_t_pos: input_t_pos, # 触发词位置向量
                model.input_c_pos: input_c_pos, # 候选词位置向量
                model.dropout_keep_prob: dropout_keep_prob, # drop_out 概率
#                 model.sentence_features : sentence_features, # 句子级别的特征 这里每一个词都有其上下文组成
                model.input_t_context:input_t_context, # 触发词以及其上下文
                model.input_c_context:input_c_context  # 候选词以及上下文
            }
            _, loss, accuracy = sess.run(
                [train_op, loss, accuracy],
                feed_dict)
            time_str = datetime.datetime.now().isoformat()
            print("stype:{}, {}: , loss {:g}, acc {:g}".format(stype, epoch, loss, accuracy))


        # 测试阶段不需要计算梯度 也不需要进行权值更新 仅仅需要计算acc的值
        def eval_step(input_x, input_event_y, input_role_y, input_t, input_c, input_t_pos, input_c_pos, dropout_keep_prob
                      , sentence_features, input_t_context, input_c_context,accuracy, predicts, stype):
            feed_dict = {
                model.input_x: input_x, # 句子级别特征
                model.input_event_y: input_event_y, # 事件类别
                model.input_role_y: input_role_y, # 角色类别
                # model.input_t:input_t,  # 触发词
                # model.input_c:input_c,  # 候选词
                model.input_t_pos: input_t_pos,   # 触发词位置向量
                model.input_c_pos: input_c_pos,   # 候选词位置向量
                model.dropout_keep_prob: dropout_keep_prob,  # drop_out 概率
#                 model.sentence_features: sentence_features,  # 句子级别的特征 这里每一个词都有其上下文组成
                model.input_t_context: input_t_context,  # 触发词以及其上下文
                model.input_c_context: input_c_context   # 候选词以及上下文
            }
            accuracy, predicts = sess.run([accuracy, predicts], feed_dict) 
            print ("{} eval accuracy:{}".format(stype, accuracy))
            return predicts


        for i in range(num_epochs):
            for j in range(datas.instances_size // data_batch_size):
                x, t, c, y_e, y_r, pos_c, pos_t, sentences_f, c_context, t_context, _ = datas.next_cnn_data()
#                 print ", ".join(map(lambda t:datas.all_words[t]  , x[0])) 
            #     事件类型预测 
            train_step(input_x=x, input_event_y=y_e, input_role_y=y_r,
                           input_t=t, input_c=c, input_c_pos=pos_c, input_t_pos=pos_t,
                           dropout_keep_prob=0.8, sentence_features=sentences_f, 
                           input_t_context= t_context,input_c_context = c_context,
                           train_op = train_op_event, loss=model.loss_event,accuracy=model.accuracy_event,
                           epoch = i, stype="event"
                          )
            #     角色类型预测
            train_step(input_x=x, input_event_y=y_e, input_role_y=y_r,
                           input_t=t, input_c=c, input_c_pos=pos_c, input_t_pos=pos_t,
                           dropout_keep_prob=0.8, sentence_features=sentences_f, 
                           input_t_context= t_context,input_c_context = c_context,
                           train_op = train_op_role, loss=model.loss_role,accuracy=model.accuracy_role,
                           epoch = i, stype="role"
                          )
        # john.zhang 2016-12-16 最后50个instance作为测试集 用于测试数据
        print "----------------------------华丽的分割线-----------------------------------------"
        x, t, c, y_e, y_r, pos_c, pos_t, sentences_f, c_context, t_context, _ = datas.eval_cnn_data()
        # 事件类型预测
        predicts_event = eval_step(input_x=x, input_event_y=y_e, input_role_y=y_r, input_t=t, input_c=c, input_c_pos=pos_c, input_t_pos=pos_t,
                  dropout_keep_prob=1.0, sentence_features=sentences_f, input_t_context=t_context,
                  input_c_context=c_context, accuracy=model.accuracy_event, predicts=model.predicts_event, stype="event")
        # 角色类型预测
        predicts_role = eval_step(input_x=x, input_event_y=y_e, input_role_y=y_r, input_t=t, input_c=c, input_c_pos=pos_c, input_t_pos=pos_t,
                  dropout_keep_prob=1.0, sentence_features=sentences_f, input_t_context=t_context,
                  input_c_context=c_context, accuracy=model.accuracy_role, predicts=model.predicts_role, stype="role")
        convert_event = {0:"非事件", 1:"股票增长类事件", 2:"股票降低类事件", 3:"股票异动类事件", 4:"股票交易类事件", 
                        5:"业绩上升类事件",6:"业绩下滑类事件",7:"产品涨价类事件",8:"产品跌价类事件"
                        }    # 事件类型准换
        convert_role = {0:"其它角色", 1:"施事角色", 2:"受事角色", 3:"时间角色", 4:"地点角色", 5:"数字角色"}    # 角色类型转换
        # 输出测试结果
        for i in range(len(x)):
            print "输入数据：{}".format(", ".join(map(lambda h: datas.all_words[h], x[i])))
            print "触发词：{}".format(", ".join(map(lambda h: datas.all_words[h], t[i])))
            print "候选词：{}".format(", ".join(map(lambda h: datas.all_words[h], c[i])))
            print "预测事件类别:{}".format(convert_event[predicts_event[i]])
            print "预测角色类别:{}".format(convert_role[predicts_role[i]])
#             print "----------------------------华丽的分割线-----------------------------------------"
# Out:
# Writing to /home/njit/Deeplearning/John_toturial/ace/ace_cnn_model_02/1482228870
#
# stype:event, 0: , loss 2.26476, acc 0.05
# stype:role, 0: , loss 1.42324, acc 0.6
# stype:event, 1: , loss 2.18153, acc 0.2
# stype:role, 1: , loss 1.3998, acc 0.65
# stype:event, 2: , loss 2.17465, acc 0.2
# stype:role, 2: , loss 1.69209, acc 0.35
# stype:event, 3: , loss 2.14667, acc 0.2
# stype:role, 3: , loss 1.34516, acc 0.7
# stype:event, 4: , loss 2.16122, acc 0.2
# stype:role, 4: , loss 1.54305, acc 0.5
# stype:event, 5: , loss 2.17909, acc 0.2
# stype:role, 5: , loss 1.54361, acc 0.5
# stype:event, 6: , loss 2.23683, acc 0.15
# stype:role, 6: , loss 1.59362, acc 0.45
# stype:event, 7: , loss 2.16029, acc 0.2
# stype:role, 7: , loss 1.44372, acc 0.6
# stype:event, 8: , loss 2.0713, acc 0.3
# stype:role, 8: , loss 1.38837, acc 0.65
# stype:event, 9: , loss 2.26456, acc 0.1
# stype:role, 9: , loss 1.44359, acc 0.6
# stype:event, 10: , loss 2.21984, acc 0.15
# stype:role, 10: , loss 1.4935, acc 0.55
# stype:event, 11: , loss 2.16749, acc 0.2
# stype:role, 11: , loss 1.44279, acc 0.6
# stype:event, 12: , loss 2.22053, acc 0.15
# stype:role, 12: , loss 1.14359, acc 0.9
# stype:event, 13: , loss 2.07273, acc 0.3
# stype:role, 13: , loss 1.4436, acc 0.6
# stype:event, 14: , loss 2.22041, acc 0.15
# stype:role, 14: , loss 1.39357, acc 0.65
# stype:event, 15: , loss 2.02025, acc 0.35
# stype:role, 15: , loss 1.49359, acc 0.55
# stype:event, 16: , loss 2.11847, acc 0.25
# stype:role, 16: , loss 1.59322, acc 0.45
# stype:event, 17: , loss 2.17179, acc 0.2
# stype:role, 17: , loss 1.54359, acc 0.5
# stype:event, 18: , loss 2.02064, acc 0.35
# stype:role, 18: , loss 1.54358, acc 0.5
# stype:event, 19: , loss 2.21988, acc 0.15
# stype:role, 19: , loss 1.54359, acc 0.5
# stype:event, 20: , loss 2.22169, acc 0.15
# stype:role, 20: , loss 1.54359, acc 0.5
# stype:event, 21: , loss 2.21879, acc 0.15
# stype:role, 21: , loss 1.54359, acc 0.5
# stype:event, 22: , loss 2.22148, acc 0.15
# stype:role, 22: , loss 1.59358, acc 0.45
# stype:event, 23: , loss 2.12148, acc 0.25
# stype:role, 23: , loss 1.54359, acc 0.5
# stype:event, 24: , loss 2.11893, acc 0.25
# stype:role, 24: , loss 1.34359, acc 0.7
# stype:event, 25: , loss 2.06293, acc 0.3
# stype:role, 25: , loss 1.44336, acc 0.6
# stype:event, 26: , loss 2.22048, acc 0.15
# stype:role, 26: , loss 1.29347, acc 0.75
# stype:event, 27: , loss 2.21865, acc 0.15
# stype:role, 27: , loss 1.54359, acc 0.5
# stype:event, 28: , loss 2.03882, acc 0.3
# stype:role, 28: , loss 1.24357, acc 0.8
# stype:event, 29: , loss 2.13775, acc 0.25
# stype:role, 29: , loss 1.54357, acc 0.5
# stype:event, 30: , loss 2.29703, acc 0.05
# stype:role, 30: , loss 1.54348, acc 0.5
# stype:event, 31: , loss 2.13691, acc 0.25
# stype:role, 31: , loss 1.34356, acc 0.7
# stype:event, 32: , loss 2.14941, acc 0.2
# stype:role, 32: , loss 1.34365, acc 0.7
# stype:event, 33: , loss 2.23594, acc 0.15
# stype:role, 33: , loss 1.29359, acc 0.75
# stype:event, 34: , loss 1.98973, acc 0.35
# stype:role, 34: , loss 1.54359, acc 0.5
# stype:event, 35: , loss 2.13862, acc 0.2
# stype:role, 35: , loss 1.59351, acc 0.45
# stype:event, 36: , loss 2.14825, acc 0.15
# stype:role, 36: , loss 1.49347, acc 0.55
# stype:event, 37: , loss 2.30523, acc 0.05
# stype:role, 37: , loss 1.34358, acc 0.7
# stype:event, 38: , loss 2.15002, acc 0.2
# stype:role, 38: , loss 1.54359, acc 0.5
# stype:event, 39: , loss 1.88807, acc 0.5
# stype:role, 39: , loss 1.4436, acc 0.6
# stype:event, 40: , loss 2.1983, acc 0.15
# stype:role, 40: , loss 1.39262, acc 0.65
# stype:event, 41: , loss 2.07858, acc 0.3
# stype:role, 41: , loss 1.44341, acc 0.6
# stype:event, 42: , loss 2.00192, acc 0.35
# stype:role, 42: , loss 1.34353, acc 0.7
# stype:event, 43: , loss 2.05587, acc 0.3
# stype:role, 43: , loss 1.54354, acc 0.5
# stype:event, 44: , loss 2.06654, acc 0.3
# stype:role, 44: , loss 1.44359, acc 0.6
# stype:event, 45: , loss 2.03416, acc 0.3
# stype:role, 45: , loss 1.59354, acc 0.45
# stype:event, 46: , loss 2.10154, acc 0.25
# stype:role, 46: , loss 1.64359, acc 0.4
# stype:event, 47: , loss 2.03971, acc 0.3
# stype:role, 47: , loss 1.44355, acc 0.6
# stype:event, 48: , loss 2.16209, acc 0.2
# stype:role, 48: , loss 1.3936, acc 0.65
# stype:event, 49: , loss 2.07397, acc 0.3
# stype:role, 49: , loss 1.29349, acc 0.75
# stype:event, 50: , loss 2.03137, acc 0.35
# stype:role, 50: , loss 1.39365, acc 0.65
# stype:event, 51: , loss 2.22383, acc 0.1
# stype:role, 51: , loss 1.48441, acc 0.55
# stype:event, 52: , loss 1.77056, acc 0.6
# stype:role, 52: , loss 1.44359, acc 0.6
# stype:event, 53: , loss 2.12895, acc 0.25
# stype:role, 53: , loss 1.54358, acc 0.5
# stype:event, 54: , loss 2.00545, acc 0.35
# stype:role, 54: , loss 1.29361, acc 0.75
# stype:event, 55: , loss 1.90706, acc 0.5
# stype:role, 55: , loss 1.49361, acc 0.55
# stype:event, 56: , loss 2.03581, acc 0.35
# stype:role, 56: , loss 1.49376, acc 0.55
# stype:event, 57: , loss 1.9067, acc 0.4
# stype:role, 57: , loss 1.34275, acc 0.7
# stype:event, 58: , loss 2.01556, acc 0.4
# stype:role, 58: , loss 1.59355, acc 0.45
# stype:event, 59: , loss 1.96837, acc 0.4
# stype:role, 59: , loss 1.2931, acc 0.75
# stype:event, 60: , loss 1.88712, acc 0.45
# stype:role, 60: , loss 1.39715, acc 0.65
# stype:event, 61: , loss 1.96, acc 0.35
# stype:role, 61: , loss 1.46042, acc 0.6
# stype:event, 62: , loss 1.86084, acc 0.45
# stype:role, 62: , loss 1.41392, acc 0.65
# stype:event, 63: , loss 1.91553, acc 0.4
# stype:role, 63: , loss 1.59182, acc 0.45
# stype:event, 64: , loss 1.95791, acc 0.4
# stype:role, 64: , loss 1.38893, acc 0.65
# stype:event, 65: , loss 1.77558, acc 0.55
# stype:role, 65: , loss 1.49729, acc 0.55
# stype:event, 66: , loss 1.74184, acc 0.6
# stype:role, 66: , loss 1.4426, acc 0.6
# stype:event, 67: , loss 1.79963, acc 0.6
# stype:role, 67: , loss 1.44598, acc 0.6
# stype:event, 68: , loss 1.86991, acc 0.5
# stype:role, 68: , loss 1.34779, acc 0.7
# stype:event, 69: , loss 1.77157, acc 0.6
# stype:role, 69: , loss 1.41677, acc 0.65
# stype:event, 70: , loss 1.76952, acc 0.6
# stype:role, 70: , loss 1.27051, acc 0.8
# stype:event, 71: , loss 1.85638, acc 0.5
# stype:role, 71: , loss 1.43618, acc 0.6
# stype:event, 72: , loss 1.80644, acc 0.55
# stype:role, 72: , loss 1.39531, acc 0.65
# stype:event, 73: , loss 1.95551, acc 0.4
# stype:role, 73: , loss 1.4386, acc 0.6
# stype:event, 74: , loss 1.93608, acc 0.45
# stype:role, 74: , loss 1.54311, acc 0.5
# stype:event, 75: , loss 1.70823, acc 0.65
# stype:role, 75: , loss 1.34153, acc 0.7
# stype:event, 76: , loss 1.71805, acc 0.7
# stype:role, 76: , loss 1.29361, acc 0.75
# stype:event, 77: , loss 1.74699, acc 0.6
# stype:role, 77: , loss 1.49378, acc 0.55
# stype:event, 78: , loss 1.75822, acc 0.6
# stype:role, 78: , loss 1.39271, acc 0.65
# stype:event, 79: , loss 1.70962, acc 0.65
# stype:role, 79: , loss 1.29355, acc 0.75
# stype:event, 80: , loss 1.6047, acc 0.8
# stype:role, 80: , loss 1.3908, acc 0.65
# stype:event, 81: , loss 1.44705, acc 0.95
# stype:role, 81: , loss 1.39362, acc 0.65
# stype:event, 82: , loss 1.8841, acc 0.45
# stype:role, 82: , loss 1.53908, acc 0.5
# stype:event, 83: , loss 1.89962, acc 0.45
# stype:role, 83: , loss 1.39781, acc 0.65
# stype:event, 84: , loss 1.74616, acc 0.65
# stype:role, 84: , loss 1.49236, acc 0.55
# stype:event, 85: , loss 1.78255, acc 0.6
# stype:role, 85: , loss 1.434, acc 0.6
# stype:event, 86: , loss 1.76173, acc 0.6
# stype:role, 86: , loss 1.39378, acc 0.65
# stype:event, 87: , loss 1.62871, acc 0.75
# stype:role, 87: , loss 1.44241, acc 0.6
# stype:event, 88: , loss 1.49909, acc 0.9
# stype:role, 88: , loss 1.70226, acc 0.35
# stype:event, 89: , loss 1.75907, acc 0.6
# stype:role, 89: , loss 1.55811, acc 0.5
# stype:event, 90: , loss 1.72541, acc 0.65
# stype:role, 90: , loss 1.50421, acc 0.55
# stype:event, 91: , loss 1.65207, acc 0.75
# stype:role, 91: , loss 1.44323, acc 0.6
# stype:event, 92: , loss 1.69198, acc 0.7
# stype:role, 92: , loss 1.53974, acc 0.5
# stype:event, 93: , loss 1.83834, acc 0.55
# stype:role, 93: , loss 1.29958, acc 0.75
# stype:event, 94: , loss 1.77242, acc 0.6
# stype:role, 94: , loss 1.29572, acc 0.75
# stype:event, 95: , loss 1.56289, acc 0.85
# stype:role, 95: , loss 1.44451, acc 0.6
# stype:event, 96: , loss 1.66618, acc 0.7
# stype:role, 96: , loss 1.53768, acc 0.5
# stype:event, 97: , loss 1.60725, acc 0.75
# stype:role, 97: , loss 1.56986, acc 0.45
# stype:event, 98: , loss 1.76924, acc 0.6
# stype:role, 98: , loss 1.39759, acc 0.65
# stype:event, 99: , loss 1.66826, acc 0.7
# stype:role, 99: , loss 1.49337, acc 0.55
# stype:event, 100: , loss 1.97874, acc 0.4
# stype:role, 100: , loss 1.39667, acc 0.65
# stype:event, 101: , loss 1.68586, acc 0.7
# stype:role, 101: , loss 1.59649, acc 0.45
# stype:event, 102: , loss 1.874, acc 0.5
# stype:role, 102: , loss 1.57408, acc 0.45
# stype:event, 103: , loss 1.7162, acc 0.7
# stype:role, 103: , loss 1.67543, acc 0.35
# stype:event, 104: , loss 1.63142, acc 0.75
# stype:role, 104: , loss 1.5968, acc 0.45
# stype:event, 105: , loss 1.53401, acc 0.85
# stype:role, 105: , loss 1.33606, acc 0.7
# stype:event, 106: , loss 1.75394, acc 0.6
# stype:role, 106: , loss 1.44051, acc 0.6
# stype:event, 107: , loss 1.62714, acc 0.75
# stype:role, 107: , loss 1.50381, acc 0.55
# stype:event, 108: , loss 1.89267, acc 0.45
# stype:role, 108: , loss 1.34704, acc 0.7
# stype:event, 109: , loss 1.58974, acc 0.8
# stype:role, 109: , loss 1.45395, acc 0.6
# stype:event, 110: , loss 1.76733, acc 0.6
# stype:role, 110: , loss 1.5489, acc 0.5
# stype:event, 111: , loss 1.69071, acc 0.7
# stype:role, 111: , loss 1.42466, acc 0.6
# stype:event, 112: , loss 1.54831, acc 0.85
# stype:role, 112: , loss 1.44626, acc 0.6
# stype:event, 113: , loss 1.64034, acc 0.75
# stype:role, 113: , loss 1.38633, acc 0.65
# stype:event, 114: , loss 1.60085, acc 0.8
# stype:role, 114: , loss 1.30492, acc 0.75
# stype:event, 115: , loss 1.62351, acc 0.75
# stype:role, 115: , loss 1.39296, acc 0.65
# stype:event, 116: , loss 1.57729, acc 0.8
# stype:role, 116: , loss 1.39381, acc 0.65
# stype:event, 117: , loss 1.63154, acc 0.75
# stype:role, 117: , loss 1.41176, acc 0.65
# stype:event, 118: , loss 1.86659, acc 0.5
# stype:role, 118: , loss 1.4916, acc 0.55
# stype:event, 119: , loss 1.67484, acc 0.7
# stype:role, 119: , loss 1.34027, acc 0.7
# stype:event, 120: , loss 1.72645, acc 0.65
# stype:role, 120: , loss 1.40714, acc 0.65
# stype:event, 121: , loss 1.7323, acc 0.65
# stype:role, 121: , loss 1.66483, acc 0.35
# stype:event, 122: , loss 1.7971, acc 0.6
# stype:role, 122: , loss 1.58824, acc 0.45
# stype:event, 123: , loss 1.62583, acc 0.75
# stype:role, 123: , loss 1.42415, acc 0.65
# stype:event, 124: , loss 1.63419, acc 0.75
# stype:role, 124: , loss 1.24347, acc 0.8
# stype:event, 125: , loss 1.51898, acc 0.85
# stype:role, 125: , loss 1.24201, acc 0.8
# stype:event, 126: , loss 1.47286, acc 0.9
# stype:role, 126: , loss 1.46274, acc 0.55
# stype:event, 127: , loss 1.71896, acc 0.65
# stype:role, 127: , loss 1.44411, acc 0.6
# stype:event, 128: , loss 1.62404, acc 0.75
# stype:role, 128: , loss 1.38822, acc 0.65
# stype:event, 129: , loss 1.60607, acc 0.8
# stype:role, 129: , loss 1.3381, acc 0.7
# stype:event, 130: , loss 1.64635, acc 0.75
# stype:role, 130: , loss 1.53352, acc 0.5
# stype:event, 131: , loss 1.66293, acc 0.7
# stype:role, 131: , loss 1.40203, acc 0.65
# stype:event, 132: , loss 1.80912, acc 0.55
# stype:role, 132: , loss 1.35281, acc 0.7
# stype:event, 133: , loss 1.59439, acc 0.75
# stype:role, 133: , loss 1.27084, acc 0.75
# stype:event, 134: , loss 1.62455, acc 0.75
# stype:role, 134: , loss 1.34649, acc 0.7
# stype:event, 135: , loss 1.754, acc 0.6
# stype:role, 135: , loss 1.39676, acc 0.65
# stype:event, 136: , loss 1.61717, acc 0.75
# stype:role, 136: , loss 1.5308, acc 0.5
# stype:event, 137: , loss 1.61592, acc 0.8
# stype:role, 137: , loss 1.55, acc 0.5
# stype:event, 138: , loss 1.66974, acc 0.7
# stype:role, 138: , loss 1.46325, acc 0.55
# stype:event, 139: , loss 1.69505, acc 0.7
# stype:role, 139: , loss 1.39746, acc 0.65
# stype:event, 140: , loss 1.73334, acc 0.65
# stype:role, 140: , loss 1.44125, acc 0.6
# stype:event, 141: , loss 1.57381, acc 0.8
# stype:role, 141: , loss 1.33703, acc 0.7
# stype:event, 142: , loss 1.78275, acc 0.55
# stype:role, 142: , loss 1.32009, acc 0.7
# stype:event, 143: , loss 1.67616, acc 0.7
# stype:role, 143: , loss 1.59964, acc 0.4
# stype:event, 144: , loss 1.63615, acc 0.75
# stype:role, 144: , loss 1.40359, acc 0.65
# stype:event, 145: , loss 1.62008, acc 0.75
# stype:role, 145: , loss 1.38339, acc 0.65
# stype:event, 146: , loss 1.63068, acc 0.75
# stype:role, 146: , loss 1.38981, acc 0.65
# stype:event, 147: , loss 1.62638, acc 0.75
# stype:role, 147: , loss 1.32043, acc 0.7
# stype:event, 148: , loss 1.72728, acc 0.65
# stype:role, 148: , loss 1.38243, acc 0.65
# stype:event, 149: , loss 1.57258, acc 0.8
# stype:role, 149: , loss 1.37885, acc 0.7
# stype:event, 150: , loss 1.60434, acc 0.75
# stype:role, 150: , loss 1.28782, acc 0.75
# stype:event, 151: , loss 1.79522, acc 0.6
# stype:role, 151: , loss 1.31963, acc 0.75
# stype:event, 152: , loss 1.67793, acc 0.7
# stype:role, 152: , loss 1.2061, acc 0.85
# stype:event, 153: , loss 1.77071, acc 0.6
# stype:role, 153: , loss 1.36262, acc 0.7
# stype:event, 154: , loss 1.66773, acc 0.7
# stype:role, 154: , loss 1.40107, acc 0.65
# stype:event, 155: , loss 1.73806, acc 0.6
# stype:role, 155: , loss 1.40606, acc 0.65
# stype:event, 156: , loss 1.61926, acc 0.75
# stype:role, 156: , loss 1.41768, acc 0.65
# stype:event, 157: , loss 1.78434, acc 0.6
# stype:role, 157: , loss 1.43405, acc 0.6
# stype:event, 158: , loss 1.62068, acc 0.75
# stype:role, 158: , loss 1.24125, acc 0.8
# stype:event, 159: , loss 1.52625, acc 0.85
# stype:role, 159: , loss 1.25418, acc 0.8
# stype:event, 160: , loss 1.71557, acc 0.65
# stype:role, 160: , loss 1.39019, acc 0.65
# stype:event, 161: , loss 1.65284, acc 0.75
# stype:role, 161: , loss 1.35172, acc 0.7
# stype:event, 162: , loss 1.81782, acc 0.55
# stype:role, 162: , loss 1.28224, acc 0.75
# stype:event, 163: , loss 1.54722, acc 0.85
# stype:role, 163: , loss 1.39018, acc 0.65
# stype:event, 164: , loss 1.62102, acc 0.75
# stype:role, 164: , loss 1.19225, acc 0.85
# stype:event, 165: , loss 1.7009, acc 0.65
# stype:role, 165: , loss 1.35956, acc 0.7
# stype:event, 166: , loss 1.7209, acc 0.65
# stype:role, 166: , loss 1.31245, acc 0.75
# stype:event, 167: , loss 1.75321, acc 0.6
# stype:role, 167: , loss 1.26343, acc 0.8
# stype:event, 168: , loss 1.63863, acc 0.75
# stype:role, 168: , loss 1.37374, acc 0.65
# stype:event, 169: , loss 1.626, acc 0.75
# stype:role, 169: , loss 1.25492, acc 0.8
# stype:event, 170: , loss 1.5462, acc 0.85
# stype:role, 170: , loss 1.49072, acc 0.5
# stype:event, 171: , loss 1.68118, acc 0.7
# stype:role, 171: , loss 1.37919, acc 0.65
# stype:event, 172: , loss 1.65148, acc 0.75
# stype:role, 172: , loss 1.31058, acc 0.75
# stype:event, 173: , loss 1.61461, acc 0.75
# stype:role, 173: , loss 1.35027, acc 0.7
# stype:event, 174: , loss 1.7713, acc 0.6
# stype:role, 174: , loss 1.3564, acc 0.65
# stype:event, 175: , loss 1.7167, acc 0.65
# stype:role, 175: , loss 1.22591, acc 0.85
# stype:event, 176: , loss 1.78073, acc 0.6
# stype:role, 176: , loss 1.25055, acc 0.8
# stype:event, 177: , loss 1.53655, acc 0.85
# stype:role, 177: , loss 1.27067, acc 0.8
# stype:event, 178: , loss 1.66752, acc 0.7
# stype:role, 178: , loss 1.26032, acc 0.8
# stype:event, 179: , loss 1.64403, acc 0.75
# stype:role, 179: , loss 1.24979, acc 0.8
# stype:event, 180: , loss 1.59486, acc 0.8
# stype:role, 180: , loss 1.30424, acc 0.8
# stype:event, 181: , loss 1.55306, acc 0.85
# stype:role, 181: , loss 1.40306, acc 0.65
# stype:event, 182: , loss 1.70136, acc 0.65
# stype:role, 182: , loss 1.29796, acc 0.8
# stype:event, 183: , loss 1.79467, acc 0.55
# stype:role, 183: , loss 1.49047, acc 0.6
# stype:event, 184: , loss 1.74433, acc 0.65
# stype:role, 184: , loss 1.25221, acc 0.8
# stype:event, 185: , loss 1.70658, acc 0.65
# stype:role, 185: , loss 1.22401, acc 0.85
# stype:event, 186: , loss 1.7699, acc 0.6
# stype:role, 186: , loss 1.39332, acc 0.65
# stype:event, 187: , loss 1.64185, acc 0.75
# stype:role, 187: , loss 1.23081, acc 0.85
# stype:event, 188: , loss 1.65906, acc 0.7
# stype:role, 188: , loss 1.2616, acc 0.75
# stype:event, 189: , loss 1.67364, acc 0.7
# stype:role, 189: , loss 1.33202, acc 0.7
# stype:event, 190: , loss 1.4902, acc 0.9
# stype:role, 190: , loss 1.25135, acc 0.8
# stype:event, 191: , loss 1.64696, acc 0.75
# stype:role, 191: , loss 1.32847, acc 0.75
# stype:event, 192: , loss 1.67909, acc 0.7
# stype:role, 192: , loss 1.44516, acc 0.55
# stype:event, 193: , loss 1.63248, acc 0.75
# stype:role, 193: , loss 1.22184, acc 0.85
# stype:event, 194: , loss 1.75828, acc 0.6
# stype:role, 194: , loss 1.27206, acc 0.8
# stype:event, 195: , loss 1.69797, acc 0.65
# stype:role, 195: , loss 1.2344, acc 0.8
# stype:event, 196: , loss 1.4708, acc 0.9
# stype:role, 196: , loss 1.09256, acc 0.95
# stype:event, 197: , loss 1.62798, acc 0.75
# stype:role, 197: , loss 1.32955, acc 0.7
# stype:event, 198: , loss 1.76549, acc 0.6
# stype:role, 198: , loss 1.3179, acc 0.7
# stype:event, 199: , loss 1.61028, acc 0.75
# stype:role, 199: , loss 1.31827, acc 0.7
# stype:event, 200: , loss 1.6589, acc 0.7
# stype:role, 200: , loss 1.24277, acc 0.8
# stype:event, 201: , loss 1.6779, acc 0.7
# stype:role, 201: , loss 1.45178, acc 0.6
# stype:event, 202: , loss 1.71613, acc 0.65
# stype:role, 202: , loss 1.25423, acc 0.8
# stype:event, 203: , loss 1.55252, acc 0.8
# stype:role, 203: , loss 1.32362, acc 0.7
# stype:event, 204: , loss 1.57989, acc 0.8
# stype:role, 204: , loss 1.30924, acc 0.75
# stype:event, 205: , loss 1.76556, acc 0.6
# stype:role, 205: , loss 1.29014, acc 0.75
# stype:event, 206: , loss 1.5823, acc 0.8
# stype:role, 206: , loss 1.30417, acc 0.75
# stype:event, 207: , loss 1.86167, acc 0.55
# stype:role, 207: , loss 1.39898, acc 0.65
# stype:event, 208: , loss 1.74155, acc 0.6
# stype:role, 208: , loss 1.38695, acc 0.65
# stype:event, 209: , loss 1.814, acc 0.55
# stype:role, 209: , loss 1.19326, acc 0.85
# stype:event, 210: , loss 1.70813, acc 0.65
# stype:role, 210: , loss 1.26907, acc 0.75
# stype:event, 211: , loss 1.52848, acc 0.85
# stype:role, 211: , loss 1.31234, acc 0.75
# stype:event, 212: , loss 1.69155, acc 0.7
# stype:role, 212: , loss 1.35621, acc 0.7
# stype:event, 213: , loss 1.64558, acc 0.75
# stype:role, 213: , loss 1.17751, acc 0.85
# stype:event, 214: , loss 1.58073, acc 0.8
# stype:role, 214: , loss 1.20343, acc 0.85
# stype:event, 215: , loss 1.47844, acc 0.9
# stype:role, 215: , loss 1.3106, acc 0.7
# stype:event, 216: , loss 1.5758, acc 0.8
# stype:role, 216: , loss 1.24548, acc 0.8
# stype:event, 217: , loss 1.62002, acc 0.75
# stype:role, 217: , loss 1.29677, acc 0.8
# stype:event, 218: , loss 1.69835, acc 0.7
# stype:role, 218: , loss 1.23088, acc 0.8
# stype:event, 219: , loss 1.8121, acc 0.55
# stype:role, 219: , loss 1.15938, acc 0.9
# stype:event, 220: , loss 1.61748, acc 0.75
# stype:role, 220: , loss 1.3161, acc 0.75
# stype:event, 221: , loss 1.4444, acc 0.95
# stype:role, 221: , loss 1.21132, acc 0.85
# stype:event, 222: , loss 1.61858, acc 0.75
# stype:role, 222: , loss 1.13809, acc 0.9
# stype:event, 223: , loss 1.61593, acc 0.75
# stype:role, 223: , loss 1.10249, acc 0.95
# stype:event, 224: , loss 1.71209, acc 0.65
# stype:role, 224: , loss 1.41805, acc 0.65
# stype:event, 225: , loss 1.66773, acc 0.7
# stype:role, 225: , loss 1.24463, acc 0.8
# stype:event, 226: , loss 1.62149, acc 0.75
# stype:role, 226: , loss 1.185, acc 0.85
# stype:event, 227: , loss 1.61758, acc 0.75
# stype:role, 227: , loss 1.2586, acc 0.8
# stype:event, 228: , loss 1.68811, acc 0.7
# stype:role, 228: , loss 1.27422, acc 0.75
# stype:event, 229: , loss 1.55527, acc 0.8
# stype:role, 229: , loss 1.26923, acc 0.75
# stype:event, 230: , loss 1.62131, acc 0.75
# stype:role, 230: , loss 1.22706, acc 0.8
# stype:event, 231: , loss 1.61886, acc 0.75
# stype:role, 231: , loss 1.15441, acc 0.9
# stype:event, 232: , loss 1.51839, acc 0.85
# stype:role, 232: , loss 1.23739, acc 0.8
# stype:event, 233: , loss 1.52096, acc 0.85
# stype:role, 233: , loss 1.29382, acc 0.75
# stype:event, 234: , loss 1.62884, acc 0.75
# stype:role, 234: , loss 1.16875, acc 0.9
# stype:event, 235: , loss 1.67088, acc 0.7
# stype:role, 235: , loss 1.12686, acc 0.95
# stype:event, 236: , loss 1.67378, acc 0.7
# stype:role, 236: , loss 1.24084, acc 0.8
# stype:event, 237: , loss 1.82296, acc 0.55
# stype:role, 237: , loss 1.24389, acc 0.8
# stype:event, 238: , loss 1.61404, acc 0.75
# stype:role, 238: , loss 1.21032, acc 0.85
# stype:event, 239: , loss 1.52634, acc 0.85
# stype:role, 239: , loss 1.25261, acc 0.8
# stype:event, 240: , loss 1.66766, acc 0.7
# stype:role, 240: , loss 1.48513, acc 0.55
# stype:event, 241: , loss 1.71473, acc 0.65
# stype:role, 241: , loss 1.21575, acc 0.85
# stype:event, 242: , loss 1.80203, acc 0.55
# stype:role, 242: , loss 1.15419, acc 0.9
# stype:event, 243: , loss 1.57535, acc 0.8
# stype:role, 243: , loss 1.20576, acc 0.85
# stype:event, 244: , loss 1.66764, acc 0.7
# stype:role, 244: , loss 1.24539, acc 0.8
# stype:event, 245: , loss 1.61705, acc 0.75
# stype:role, 245: , loss 1.14798, acc 0.9
# stype:event, 246: , loss 1.70445, acc 0.65
# stype:role, 246: , loss 1.20986, acc 0.9
# stype:event, 247: , loss 1.59171, acc 0.8
# stype:role, 247: , loss 1.0991, acc 0.95
# stype:event, 248: , loss 1.65778, acc 0.7
# stype:role, 248: , loss 1.17586, acc 0.9
# stype:event, 249: , loss 1.62301, acc 0.75
# stype:role, 249: , loss 1.20687, acc 0.85
# stype:event, 250: , loss 1.66906, acc 0.7
# stype:role, 250: , loss 1.14297, acc 0.9
# stype:event, 251: , loss 1.64213, acc 0.75
# stype:role, 251: , loss 1.10555, acc 0.95
# stype:event, 252: , loss 1.63464, acc 0.75
# stype:role, 252: , loss 1.22046, acc 0.85
# stype:event, 253: , loss 1.74468, acc 0.6
# stype:role, 253: , loss 1.19477, acc 0.85
# stype:event, 254: , loss 1.81305, acc 0.55
# stype:role, 254: , loss 1.24824, acc 0.8
# stype:event, 255: , loss 1.55022, acc 0.85
# stype:role, 255: , loss 1.29677, acc 0.75
# stype:event, 256: , loss 1.6194, acc 0.75
# stype:role, 256: , loss 1.26639, acc 0.8
# stype:event, 257: , loss 1.68237, acc 0.7
# stype:role, 257: , loss 1.24307, acc 0.8
# stype:event, 258: , loss 1.66636, acc 0.7
# stype:role, 258: , loss 1.31781, acc 0.75
# stype:event, 259: , loss 1.66211, acc 0.7
# stype:role, 259: , loss 1.39203, acc 0.65
# stype:event, 260: , loss 1.5414, acc 0.85
# stype:role, 260: , loss 1.10947, acc 0.95
# stype:event, 261: , loss 1.63436, acc 0.75
# stype:role, 261: , loss 1.24335, acc 0.8
# stype:event, 262: , loss 1.62295, acc 0.75
# stype:role, 262: , loss 1.25379, acc 0.8
# stype:event, 263: , loss 1.62612, acc 0.75
# stype:role, 263: , loss 1.29304, acc 0.75
# stype:event, 264: , loss 1.54255, acc 0.85
# stype:role, 264: , loss 1.15017, acc 0.9
# stype:event, 265: , loss 1.7598, acc 0.6
# stype:role, 265: , loss 1.26208, acc 0.8
# stype:event, 266: , loss 1.74881, acc 0.6
# stype:role, 266: , loss 1.21904, acc 0.8
# stype:event, 267: , loss 1.56699, acc 0.8
# stype:role, 267: , loss 1.24949, acc 0.8
# stype:event, 268: , loss 1.56038, acc 0.8
# stype:role, 268: , loss 1.29193, acc 0.75
# stype:event, 269: , loss 1.8137, acc 0.55
# stype:role, 269: , loss 1.28335, acc 0.75
# stype:event, 270: , loss 1.67973, acc 0.7
# stype:role, 270: , loss 1.2469, acc 0.8
# stype:event, 271: , loss 1.41578, acc 0.95
# stype:role, 271: , loss 1.22097, acc 0.85
# stype:event, 272: , loss 1.69486, acc 0.7
# stype:role, 272: , loss 1.19723, acc 0.85
# stype:event, 273: , loss 1.62982, acc 0.75
# stype:role, 273: , loss 1.0911, acc 0.95
# stype:event, 274: , loss 1.55597, acc 0.8
# stype:role, 274: , loss 1.15892, acc 0.9
# stype:event, 275: , loss 1.64555, acc 0.7
# stype:role, 275: , loss 1.33816, acc 0.7
# stype:event, 276: , loss 1.61484, acc 0.75
# stype:role, 276: , loss 1.27602, acc 0.8
# stype:event, 277: , loss 1.51623, acc 0.85
# stype:role, 277: , loss 1.20914, acc 0.85
# stype:event, 278: , loss 1.61345, acc 0.75
# stype:role, 278: , loss 1.0602, acc 1
# stype:event, 279: , loss 1.56733, acc 0.8
# stype:role, 279: , loss 1.20455, acc 0.85
# stype:event, 280: , loss 1.69609, acc 0.65
# stype:role, 280: , loss 1.14564, acc 0.9
# stype:event, 281: , loss 1.5193, acc 0.85
# stype:role, 281: , loss 1.04584, acc 1
# stype:event, 282: , loss 1.63976, acc 0.75
# stype:role, 282: , loss 1.10944, acc 0.95
# stype:event, 283: , loss 1.51513, acc 0.85
# stype:role, 283: , loss 1.27865, acc 0.75
# stype:event, 284: , loss 1.73063, acc 0.6
# stype:role, 284: , loss 1.17882, acc 0.85
# stype:event, 285: , loss 1.68057, acc 0.7
# stype:role, 285: , loss 1.22838, acc 0.85
# stype:event, 286: , loss 1.71729, acc 0.65
# stype:role, 286: , loss 1.29123, acc 0.75
# stype:event, 287: , loss 1.57778, acc 0.8
# stype:role, 287: , loss 1.25366, acc 0.8
# stype:event, 288: , loss 1.49575, acc 0.9
# stype:role, 288: , loss 1.14328, acc 0.9
# stype:event, 289: , loss 1.54368, acc 0.85
# stype:role, 289: , loss 1.14578, acc 0.9
# stype:event, 290: , loss 1.46647, acc 0.95
# stype:role, 290: , loss 1.23809, acc 0.8
# stype:event, 291: , loss 1.62461, acc 0.75
# stype:role, 291: , loss 1.10616, acc 0.95
# stype:event, 292: , loss 1.50653, acc 0.85
# stype:role, 292: , loss 1.17945, acc 0.85
# stype:event, 293: , loss 1.76336, acc 0.6
# stype:role, 293: , loss 1.33945, acc 0.7
# stype:event, 294: , loss 1.66358, acc 0.7
# stype:role, 294: , loss 1.25838, acc 0.8
# stype:event, 295: , loss 1.42076, acc 0.95
# stype:role, 295: , loss 1.19065, acc 0.85
# stype:event, 296: , loss 1.5656, acc 0.8
# stype:role, 296: , loss 1.2856, acc 0.75
# stype:event, 297: , loss 1.58605, acc 0.8
# stype:role, 297: , loss 1.22011, acc 0.85
# stype:event, 298: , loss 1.63239, acc 0.75
# stype:role, 298: , loss 1.32401, acc 0.75
# stype:event, 299: , loss 1.76048, acc 0.6
# stype:role, 299: , loss 1.24399, acc 0.8
# stype:event, 300: , loss 1.57788, acc 0.8
# stype:role, 300: , loss 1.14768, acc 0.9
# stype:event, 301: , loss 1.56947, acc 0.8
# stype:role, 301: , loss 1.17816, acc 0.85
# stype:event, 302: , loss 1.61611, acc 0.75
# stype:role, 302: , loss 1.19681, acc 0.85
# stype:event, 303: , loss 1.60336, acc 0.75
# stype:role, 303: , loss 1.06487, acc 1
# stype:event, 304: , loss 1.63033, acc 0.75
# stype:role, 304: , loss 1.18739, acc 0.85
# stype:event, 305: , loss 1.49294, acc 0.9
# stype:role, 305: , loss 1.16982, acc 0.9
# stype:event, 306: , loss 1.66256, acc 0.7
# stype:role, 306: , loss 1.24673, acc 0.8
# stype:event, 307: , loss 1.66596, acc 0.7
# stype:role, 307: , loss 1.14724, acc 0.9
# stype:event, 308: , loss 1.58665, acc 0.8
# stype:role, 308: , loss 1.1477, acc 0.9
# stype:event, 309: , loss 1.54172, acc 0.8
# stype:role, 309: , loss 1.2466, acc 0.8
# stype:event, 310: , loss 1.57069, acc 0.8
# stype:role, 310: , loss 1.22825, acc 0.8
# stype:event, 311: , loss 1.51887, acc 0.85
# stype:role, 311: , loss 1.28372, acc 0.75
# stype:event, 312: , loss 1.66235, acc 0.7
# stype:role, 312: , loss 1.13498, acc 0.9
# stype:event, 313: , loss 1.51794, acc 0.85
# stype:role, 313: , loss 1.05119, acc 1
# stype:event, 314: , loss 1.70625, acc 0.65
# stype:role, 314: , loss 1.14625, acc 0.9
# stype:event, 315: , loss 1.51811, acc 0.85
# stype:role, 315: , loss 1.29328, acc 0.75
# stype:event, 316: , loss 1.50686, acc 0.9
# stype:role, 316: , loss 1.24458, acc 0.8
# stype:event, 317: , loss 1.71083, acc 0.65
# stype:role, 317: , loss 1.21232, acc 0.85
# stype:event, 318: , loss 1.46732, acc 0.9
# stype:role, 318: , loss 1.20624, acc 0.85
# stype:event, 319: , loss 1.54751, acc 0.85
# stype:role, 319: , loss 1.31696, acc 0.7
# stype:event, 320: , loss 1.65092, acc 0.7
# stype:role, 320: , loss 1.19202, acc 0.85
# stype:event, 321: , loss 1.63849, acc 0.75
# stype:role, 321: , loss 1.23585, acc 0.8
# stype:event, 322: , loss 1.66621, acc 0.65
# stype:role, 322: , loss 1.21044, acc 0.85
# stype:event, 323: , loss 1.48197, acc 0.9
# stype:role, 323: , loss 1.30121, acc 0.75
# stype:event, 324: , loss 1.49885, acc 0.85
# stype:role, 324: , loss 1.26177, acc 0.75
# stype:event, 325: , loss 1.54238, acc 0.85
# stype:role, 325: , loss 1.14341, acc 0.9
# stype:event, 326: , loss 1.62417, acc 0.75
# stype:role, 326: , loss 1.2655, acc 0.8
# stype:event, 327: , loss 1.52676, acc 0.85
# stype:role, 327: , loss 1.27254, acc 0.75
# stype:event, 328: , loss 1.70574, acc 0.65
# stype:role, 328: , loss 1.21034, acc 0.8
# stype:event, 329: , loss 1.44693, acc 0.9
# stype:role, 329: , loss 1.23291, acc 0.8
# stype:event, 330: , loss 1.42265, acc 0.95
# stype:role, 330: , loss 1.19191, acc 0.85
# stype:event, 331: , loss 1.64953, acc 0.7
# stype:role, 331: , loss 1.09989, acc 0.95
# stype:event, 332: , loss 1.57085, acc 0.8
# stype:role, 332: , loss 1.19614, acc 0.85
# stype:event, 333: , loss 1.53507, acc 0.85
# stype:role, 333: , loss 1.1625, acc 0.9
# stype:event, 334: , loss 1.52826, acc 0.85
# stype:role, 334: , loss 1.14751, acc 0.9
# stype:event, 335: , loss 1.56757, acc 0.8
# stype:role, 335: , loss 1.21373, acc 0.85
# stype:event, 336: , loss 1.49256, acc 0.9
# stype:role, 336: , loss 1.12934, acc 0.95
# stype:event, 337: , loss 1.5941, acc 0.75
# stype:role, 337: , loss 1.08898, acc 0.95
# stype:event, 338: , loss 1.516, acc 0.85
# stype:role, 338: , loss 1.11222, acc 0.95
# stype:event, 339: , loss 1.73523, acc 0.6
# stype:role, 339: , loss 1.22858, acc 0.85
# stype:event, 340: , loss 1.69864, acc 0.65
# stype:role, 340: , loss 1.12035, acc 0.95
# stype:event, 341: , loss 1.46942, acc 0.9
# stype:role, 341: , loss 1.32322, acc 0.7
# stype:event, 342: , loss 1.42351, acc 0.95
# stype:role, 342: , loss 1.17144, acc 0.9
# stype:event, 343: , loss 1.52113, acc 0.85
# stype:role, 343: , loss 1.10443, acc 0.95
# stype:event, 344: , loss 1.67535, acc 0.65
# stype:role, 344: , loss 1.04859, acc 1
# stype:event, 345: , loss 1.64039, acc 0.7
# stype:role, 345: , loss 1.09489, acc 0.95
# stype:event, 346: , loss 1.51778, acc 0.85
# stype:role, 346: , loss 1.14601, acc 0.9
# stype:event, 347: , loss 1.76253, acc 0.6
# stype:role, 347: , loss 1.14342, acc 0.9
# stype:event, 348: , loss 1.60413, acc 0.75
# stype:role, 348: , loss 1.11889, acc 0.95
# stype:event, 349: , loss 1.58411, acc 0.8
# stype:role, 349: , loss 1.10117, acc 0.95
# stype:event, 350: , loss 1.52146, acc 0.85
# stype:role, 350: , loss 1.16574, acc 0.9
# stype:event, 351: , loss 1.55133, acc 0.8
# stype:role, 351: , loss 1.12631, acc 0.9
# stype:event, 352: , loss 1.572, acc 0.8
# stype:role, 352: , loss 1.15014, acc 0.9
# stype:event, 353: , loss 1.64402, acc 0.7
# stype:role, 353: , loss 1.15351, acc 0.9
# stype:event, 354: , loss 1.71375, acc 0.65
# stype:role, 354: , loss 1.12114, acc 0.95
# stype:event, 355: , loss 1.60686, acc 0.75
# stype:role, 355: , loss 1.18663, acc 0.85
# stype:event, 356: , loss 1.58046, acc 0.8
# stype:role, 356: , loss 1.16649, acc 0.9
# stype:event, 357: , loss 1.48303, acc 0.9
# stype:role, 357: , loss 1.16759, acc 0.9
# stype:event, 358: , loss 1.50474, acc 0.85
# stype:role, 358: , loss 1.163, acc 0.9
# stype:event, 359: , loss 1.4687, acc 0.9
# stype:role, 359: , loss 1.21447, acc 0.85
# stype:event, 360: , loss 1.56575, acc 0.8
# stype:role, 360: , loss 1.10273, acc 0.95
# stype:event, 361: , loss 1.42754, acc 0.95
# stype:role, 361: , loss 1.08707, acc 0.95
# stype:event, 362: , loss 1.66615, acc 0.7
# stype:role, 362: , loss 1.10646, acc 0.95
# stype:event, 363: , loss 1.58041, acc 0.8
# stype:role, 363: , loss 1.22024, acc 0.85
# stype:event, 364: , loss 1.57129, acc 0.8
# stype:role, 364: , loss 1.33901, acc 0.7
# stype:event, 365: , loss 1.5513, acc 0.85
# stype:role, 365: , loss 1.1546, acc 0.9
# stype:event, 366: , loss 1.40194, acc 1
# stype:role, 366: , loss 1.1642, acc 0.9
# stype:event, 367: , loss 1.57416, acc 0.8
# stype:role, 367: , loss 1.09861, acc 0.95
# stype:event, 368: , loss 1.66358, acc 0.7
# stype:role, 368: , loss 1.18853, acc 0.85
# stype:event, 369: , loss 1.66362, acc 0.7
# stype:role, 369: , loss 1.17599, acc 0.85
# stype:event, 370: , loss 1.44099, acc 0.95
# stype:role, 370: , loss 1.15588, acc 0.9
# stype:event, 371: , loss 1.56663, acc 0.8
# stype:role, 371: , loss 1.19619, acc 0.85
# stype:event, 372: , loss 1.52006, acc 0.85
# stype:role, 372: , loss 1.19454, acc 0.85
# stype:event, 373: , loss 1.47256, acc 0.9
# stype:role, 373: , loss 1.09796, acc 0.95
# stype:event, 374: , loss 1.68125, acc 0.7
# stype:role, 374: , loss 1.14727, acc 0.9
# stype:event, 375: , loss 1.43664, acc 0.95
# stype:role, 375: , loss 1.18912, acc 0.85
# stype:event, 376: , loss 1.56554, acc 0.8
# stype:role, 376: , loss 1.1524, acc 0.9
# stype:event, 377: , loss 1.4701, acc 0.9
# stype:role, 377: , loss 1.15948, acc 0.9
# stype:event, 378: , loss 1.56252, acc 0.8
# stype:role, 378: , loss 1.20241, acc 0.85
# stype:event, 379: , loss 1.67554, acc 0.7
# stype:role, 379: , loss 1.20096, acc 0.85
# stype:event, 380: , loss 1.571, acc 0.8
# stype:role, 380: , loss 1.06998, acc 0.95
# stype:event, 381: , loss 1.54977, acc 0.8
# stype:role, 381: , loss 1.23959, acc 0.8
# stype:event, 382: , loss 1.62905, acc 0.75
# stype:role, 382: , loss 1.23883, acc 0.8
# stype:event, 383: , loss 1.47666, acc 0.9
# stype:role, 383: , loss 1.09397, acc 0.95
# stype:event, 384: , loss 1.58273, acc 0.8
# stype:role, 384: , loss 1.14685, acc 0.9
# stype:event, 385: , loss 1.44735, acc 0.95
# stype:role, 385: , loss 1.20409, acc 0.85
# stype:event, 386: , loss 1.56182, acc 0.8
# stype:role, 386: , loss 1.21539, acc 0.85
# stype:event, 387: , loss 1.52509, acc 0.85
# stype:role, 387: , loss 1.26849, acc 0.8
# stype:event, 388: , loss 1.56825, acc 0.8
# stype:role, 388: , loss 1.10582, acc 0.95
# stype:event, 389: , loss 1.47355, acc 0.9
# stype:role, 389: , loss 1.0653, acc 1
# stype:event, 390: , loss 1.44954, acc 0.9
# stype:role, 390: , loss 1.23528, acc 0.8
# stype:event, 391: , loss 1.69229, acc 0.7
# stype:role, 391: , loss 1.14231, acc 0.9
# stype:event, 392: , loss 1.59808, acc 0.8
# stype:role, 392: , loss 1.39451, acc 0.65
# stype:event, 393: , loss 1.63637, acc 0.75
# stype:role, 393: , loss 1.24164, acc 0.8
# stype:event, 394: , loss 1.63552, acc 0.75
# stype:role, 394: , loss 1.16363, acc 0.9
# stype:event, 395: , loss 1.52532, acc 0.85
# stype:role, 395: , loss 1.12834, acc 0.9
# stype:event, 396: , loss 1.52221, acc 0.85
# stype:role, 396: , loss 1.19206, acc 0.85
# stype:event, 397: , loss 1.56406, acc 0.8
# stype:role, 397: , loss 1.09313, acc 0.95
# stype:event, 398: , loss 1.51748, acc 0.85
# stype:role, 398: , loss 1.31578, acc 0.7
# stype:event, 399: , loss 1.42316, acc 0.95
# stype:role, 399: , loss 1.24199, acc 0.8
# stype:event, 400: , loss 1.47793, acc 0.9
# stype:role, 400: , loss 1.18781, acc 0.85
# stype:event, 401: , loss 1.43463, acc 0.95
# stype:role, 401: , loss 1.18863, acc 0.85
# stype:event, 402: , loss 1.56873, acc 0.8
# stype:role, 402: , loss 1.19012, acc 0.85
# stype:event, 403: , loss 1.52834, acc 0.85
# stype:role, 403: , loss 1.14544, acc 0.9
# stype:event, 404: , loss 1.51953, acc 0.85
# stype:role, 404: , loss 1.12184, acc 0.9
# stype:event, 405: , loss 1.53302, acc 0.85
# stype:role, 405: , loss 1.25181, acc 0.8
# stype:event, 406: , loss 1.47422, acc 0.9
# stype:role, 406: , loss 1.21654, acc 0.85
# stype:event, 407: , loss 1.40531, acc 0.95
# stype:role, 407: , loss 1.14358, acc 0.9
# stype:event, 408: , loss 1.52189, acc 0.85
# stype:role, 408: , loss 1.14519, acc 0.9
# stype:event, 409: , loss 1.59626, acc 0.75
# stype:role, 409: , loss 1.11836, acc 0.9
# stype:event, 410: , loss 1.52913, acc 0.85
# stype:role, 410: , loss 1.25565, acc 0.8
# stype:event, 411: , loss 1.4746, acc 0.9
# stype:role, 411: , loss 1.19557, acc 0.85
# stype:event, 412: , loss 1.62018, acc 0.75
# stype:role, 412: , loss 1.17084, acc 0.85
# stype:event, 413: , loss 1.57023, acc 0.8
# stype:role, 413: , loss 1.1982, acc 0.85
# stype:event, 414: , loss 1.56684, acc 0.8
# stype:role, 414: , loss 1.2744, acc 0.75
# stype:event, 415: , loss 1.61514, acc 0.75
# stype:role, 415: , loss 1.15358, acc 0.9
# stype:event, 416: , loss 1.52233, acc 0.85
# stype:role, 416: , loss 1.21357, acc 0.85
# stype:event, 417: , loss 1.46986, acc 0.9
# stype:role, 417: , loss 1.15193, acc 0.9
# stype:event, 418: , loss 1.58824, acc 0.8
# stype:role, 418: , loss 1.12664, acc 0.9
# stype:event, 419: , loss 1.64607, acc 0.7
# stype:role, 419: , loss 1.29236, acc 0.75
# stype:event, 420: , loss 1.53672, acc 0.85
# stype:role, 420: , loss 1.23559, acc 0.8
# stype:event, 421: , loss 1.47129, acc 0.9
# stype:role, 421: , loss 1.15729, acc 0.9
# stype:event, 422: , loss 1.63794, acc 0.75
# stype:role, 422: , loss 1.08344, acc 0.95
# stype:event, 423: , loss 1.53967, acc 0.8
# stype:role, 423: , loss 1.17155, acc 0.9
# stype:event, 424: , loss 1.5243, acc 0.85
# stype:role, 424: , loss 1.23755, acc 0.8
# stype:event, 425: , loss 1.3983, acc 1
# stype:role, 425: , loss 1.13804, acc 0.9
# stype:event, 426: , loss 1.65126, acc 0.7
# stype:role, 426: , loss 1.24256, acc 0.8
# stype:event, 427: , loss 1.47633, acc 0.9
# stype:role, 427: , loss 1.15204, acc 0.9
# stype:event, 428: , loss 1.57008, acc 0.8
# stype:role, 428: , loss 1.43585, acc 0.55
# stype:event, 429: , loss 1.5871, acc 0.8
# stype:role, 429: , loss 1.29906, acc 0.75
# stype:event, 430: , loss 1.52205, acc 0.85
# stype:role, 430: , loss 1.13847, acc 0.9
# stype:event, 431: , loss 1.44423, acc 0.95
# stype:role, 431: , loss 1.08481, acc 0.95
# stype:event, 432: , loss 1.4212, acc 0.95
# stype:role, 432: , loss 1.19502, acc 0.85
# stype:event, 433: , loss 1.56577, acc 0.8
# stype:role, 433: , loss 1.217, acc 0.85
# stype:event, 434: , loss 1.56949, acc 0.8
# stype:role, 434: , loss 1.19433, acc 0.85
# stype:event, 435: , loss 1.46934, acc 0.9
# stype:role, 435: , loss 1.1684, acc 0.9
# stype:event, 436: , loss 1.58061, acc 0.8
# stype:role, 436: , loss 1.04703, acc 1
# stype:event, 437: , loss 1.66813, acc 0.7
# stype:role, 437: , loss 1.14428, acc 0.9
# stype:event, 438: , loss 1.71266, acc 0.65
# stype:role, 438: , loss 1.155, acc 0.9
# stype:event, 439: , loss 1.61258, acc 0.75
# stype:role, 439: , loss 1.19293, acc 0.85
# stype:event, 440: , loss 1.51956, acc 0.85
# stype:role, 440: , loss 1.07678, acc 0.95
# stype:event, 441: , loss 1.51987, acc 0.85
# stype:role, 441: , loss 1.17185, acc 0.85
# stype:event, 442: , loss 1.63827, acc 0.75
# stype:role, 442: , loss 1.0491, acc 1
# stype:event, 443: , loss 1.51701, acc 0.85
# stype:role, 443: , loss 1.12863, acc 0.9
# stype:event, 444: , loss 1.4742, acc 0.9
# stype:role, 444: , loss 1.19562, acc 0.85
# stype:event, 445: , loss 1.51533, acc 0.85
# stype:role, 445: , loss 1.06338, acc 1
# stype:event, 446: , loss 1.70908, acc 0.65
# stype:role, 446: , loss 1.19524, acc 0.85
# stype:event, 447: , loss 1.81971, acc 0.55
# stype:role, 447: , loss 1.15048, acc 0.9
# stype:event, 448: , loss 1.46797, acc 0.9
# stype:role, 448: , loss 1.24195, acc 0.8
# stype:event, 449: , loss 1.57129, acc 0.8
# stype:role, 449: , loss 1.04484, acc 1
# stype:event, 450: , loss 1.51973, acc 0.85
# stype:role, 450: , loss 1.10419, acc 0.95
# stype:event, 451: , loss 1.42019, acc 0.95
# stype:role, 451: , loss 1.19102, acc 0.85
# stype:event, 452: , loss 1.47052, acc 0.9
# stype:role, 452: , loss 1.09487, acc 0.95
# stype:event, 453: , loss 1.52652, acc 0.85
# stype:role, 453: , loss 1.19248, acc 0.85
# stype:event, 454: , loss 1.51854, acc 0.85
# stype:role, 454: , loss 1.14291, acc 0.9
# stype:event, 455: , loss 1.56827, acc 0.8
# stype:role, 455: , loss 1.22712, acc 0.8
# stype:event, 456: , loss 1.51655, acc 0.85
# stype:role, 456: , loss 1.098, acc 0.95
# stype:event, 457: , loss 1.47789, acc 0.9
# stype:role, 457: , loss 1.18488, acc 0.85
# stype:event, 458: , loss 1.56482, acc 0.8
# stype:role, 458: , loss 1.17033, acc 0.85
# stype:event, 459: , loss 1.59733, acc 0.75
# stype:role, 459: , loss 1.12438, acc 0.9
# stype:event, 460: , loss 1.46779, acc 0.9
# stype:role, 460: , loss 1.13823, acc 0.9
# stype:event, 461: , loss 1.61466, acc 0.75
# stype:role, 461: , loss 1.19159, acc 0.85
# stype:event, 462: , loss 1.57162, acc 0.8
# stype:role, 462: , loss 1.10086, acc 0.95
# stype:event, 463: , loss 1.61533, acc 0.75
# stype:role, 463: , loss 1.26904, acc 0.8
# stype:event, 464: , loss 1.56723, acc 0.8
# stype:role, 464: , loss 1.09761, acc 0.95
# stype:event, 465: , loss 1.4707, acc 0.9
# stype:role, 465: , loss 1.09418, acc 0.95
# stype:event, 466: , loss 1.52792, acc 0.85
# stype:role, 466: , loss 1.2115, acc 0.8
# stype:event, 467: , loss 1.56806, acc 0.8
# stype:role, 467: , loss 1.14217, acc 0.9
# stype:event, 468: , loss 1.46912, acc 0.9
# stype:role, 468: , loss 1.05177, acc 1
# stype:event, 469: , loss 1.61206, acc 0.75
# stype:role, 469: , loss 1.13277, acc 0.95
# stype:event, 470: , loss 1.51949, acc 0.85
# stype:role, 470: , loss 1.16053, acc 0.9
# stype:event, 471: , loss 1.61116, acc 0.75
# stype:role, 471: , loss 1.04669, acc 1
# stype:event, 472: , loss 1.42245, acc 0.95
# stype:role, 472: , loss 1.19429, acc 0.85
# stype:event, 473: , loss 1.5571, acc 0.8
# stype:role, 473: , loss 1.37138, acc 0.65
# stype:event, 474: , loss 1.61485, acc 0.75
# stype:role, 474: , loss 1.08269, acc 0.95
# stype:event, 475: , loss 1.55202, acc 0.8
# stype:role, 475: , loss 1.28255, acc 0.8
# stype:event, 476: , loss 1.47738, acc 0.9
# stype:role, 476: , loss 1.15759, acc 0.9
# stype:event, 477: , loss 1.56597, acc 0.8
# stype:role, 477: , loss 1.17741, acc 0.85
# stype:event, 478: , loss 1.51995, acc 0.85
# stype:role, 478: , loss 1.12406, acc 0.95
# stype:event, 479: , loss 1.61447, acc 0.75
# stype:role, 479: , loss 1.0984, acc 0.95
# stype:event, 480: , loss 1.46847, acc 0.9
# stype:role, 480: , loss 1.04746, acc 1
# stype:event, 481: , loss 1.47119, acc 0.9
# stype:role, 481: , loss 1.12777, acc 0.9
# stype:event, 482: , loss 1.42691, acc 0.95
# stype:role, 482: , loss 1.20779, acc 0.85
# stype:event, 483: , loss 1.57329, acc 0.8
# stype:role, 483: , loss 1.10517, acc 0.95
# stype:event, 484: , loss 1.4696, acc 0.9
# stype:role, 484: , loss 1.04647, acc 1
# stype:event, 485: , loss 1.52287, acc 0.85
# stype:role, 485: , loss 1.04976, acc 1
# stype:event, 486: , loss 1.52386, acc 0.85
# stype:role, 486: , loss 1.25726, acc 0.8
# stype:event, 487: , loss 1.52077, acc 0.85
# stype:role, 487: , loss 1.14912, acc 0.9
# stype:event, 488: , loss 1.56917, acc 0.8
# stype:role, 488: , loss 1.14569, acc 0.9
# stype:event, 489: , loss 1.69821, acc 0.65
# stype:role, 489: , loss 1.05315, acc 1
# stype:event, 490: , loss 1.61559, acc 0.75
# stype:role, 490: , loss 1.14712, acc 0.9
# stype:event, 491: , loss 1.6146, acc 0.75
# stype:role, 491: , loss 1.19386, acc 0.85
# stype:event, 492: , loss 1.52066, acc 0.85
# stype:role, 492: , loss 1.09093, acc 0.95
# stype:event, 493: , loss 1.61341, acc 0.75
# stype:role, 493: , loss 1.09783, acc 0.95
# stype:event, 494: , loss 1.46885, acc 0.9
# stype:role, 494: , loss 1.24298, acc 0.8
# stype:event, 495: , loss 1.51721, acc 0.85
# stype:role, 495: , loss 1.04479, acc 1
# stype:event, 496: , loss 1.48488, acc 0.9
# stype:role, 496: , loss 1.2786, acc 0.75
# stype:event, 497: , loss 1.52156, acc 0.85
# stype:role, 497: , loss 1.19395, acc 0.85
# stype:event, 498: , loss 1.60487, acc 0.75
# stype:role, 498: , loss 1.0487, acc 1
# stype:event, 499: , loss 1.51979, acc 0.85
# stype:role, 499: , loss 1.09496, acc 0.95
# stype:event, 500: , loss 1.56216, acc 0.8
# stype:role, 500: , loss 1.09357, acc 0.95
# stype:event, 501: , loss 1.47273, acc 0.9
# stype:role, 501: , loss 1.0477, acc 1
# stype:event, 502: , loss 1.66337, acc 0.7
# stype:role, 502: , loss 1.25762, acc 0.8
# stype:event, 503: , loss 1.47127, acc 0.9
# stype:role, 503: , loss 1.09185, acc 0.95
# stype:event, 504: , loss 1.58796, acc 0.8
# stype:role, 504: , loss 1.04607, acc 1
# stype:event, 505: , loss 1.61425, acc 0.75
# stype:role, 505: , loss 1.20481, acc 0.85
# stype:event, 506: , loss 1.51867, acc 0.85
# stype:role, 506: , loss 1.14447, acc 0.9
# stype:event, 507: , loss 1.51599, acc 0.85
# stype:role, 507: , loss 1.04433, acc 1
# stype:event, 508: , loss 1.46865, acc 0.9
# stype:role, 508: , loss 1.09453, acc 0.95
# stype:event, 509: , loss 1.42259, acc 0.95
# stype:role, 509: , loss 1.04886, acc 1
# stype:event, 510: , loss 1.42298, acc 0.95
# stype:role, 510: , loss 1.24445, acc 0.8
# stype:event, 511: , loss 1.6151, acc 0.75
# stype:role, 511: , loss 1.23016, acc 0.8
# stype:event, 512: , loss 1.47172, acc 0.9
# stype:role, 512: , loss 1.1428, acc 0.9
# stype:event, 513: , loss 1.52217, acc 0.85
# stype:role, 513: , loss 1.11433, acc 0.95
# stype:event, 514: , loss 1.51724, acc 0.85
# stype:role, 514: , loss 1.05687, acc 1
# stype:event, 515: , loss 1.42571, acc 0.95
# stype:role, 515: , loss 1.10091, acc 0.95
# stype:event, 516: , loss 1.61551, acc 0.75
# stype:role, 516: , loss 1.04526, acc 1
# stype:event, 517: , loss 1.42128, acc 0.95
# stype:role, 517: , loss 1.1608, acc 0.9
# stype:event, 518: , loss 1.42577, acc 0.95
# stype:role, 518: , loss 1.05645, acc 1
# stype:event, 519: , loss 1.51655, acc 0.85
# stype:role, 519: , loss 1.19393, acc 0.85
# stype:event, 520: , loss 1.52165, acc 0.85
# stype:role, 520: , loss 1.19385, acc 0.85
# stype:event, 521: , loss 1.42169, acc 0.95
# stype:role, 521: , loss 1.14775, acc 0.9
# stype:event, 522: , loss 1.56625, acc 0.8
# stype:role, 522: , loss 1.0913, acc 0.95
# stype:event, 523: , loss 1.51886, acc 0.85
# stype:role, 523: , loss 1.2, acc 0.85
# stype:event, 524: , loss 1.49828, acc 0.9
# stype:role, 524: , loss 1.12867, acc 0.9
# stype:event, 525: , loss 1.71047, acc 0.65
# stype:role, 525: , loss 1.13555, acc 0.9
# stype:event, 526: , loss 1.51888, acc 0.85
# stype:role, 526: , loss 1.14178, acc 0.9
# stype:event, 527: , loss 1.61369, acc 0.75
# stype:role, 527: , loss 1.14378, acc 0.9
# stype:event, 528: , loss 1.56916, acc 0.8
# stype:role, 528: , loss 1.05422, acc 1
# stype:event, 529: , loss 1.57039, acc 0.8
# stype:role, 529: , loss 1.14508, acc 0.9
# stype:event, 530: , loss 1.56948, acc 0.8
# stype:role, 530: , loss 1.09718, acc 0.95
# stype:event, 531: , loss 1.60257, acc 0.75
# stype:role, 531: , loss 1.06093, acc 1
# stype:event, 532: , loss 1.47406, acc 0.9
# stype:role, 532: , loss 1.09205, acc 0.95
# stype:event, 533: , loss 1.51651, acc 0.85
# stype:role, 533: , loss 1.08786, acc 0.95
# stype:event, 534: , loss 1.56464, acc 0.8
# stype:role, 534: , loss 1.05518, acc 1
# stype:event, 535: , loss 1.66026, acc 0.7
# stype:role, 535: , loss 1.0974, acc 0.95
# stype:event, 536: , loss 1.51712, acc 0.85
# stype:role, 536: , loss 1.04705, acc 1
# stype:event, 537: , loss 1.61121, acc 0.75
# stype:role, 537: , loss 1.24101, acc 0.8
# stype:event, 538: , loss 1.48791, acc 0.9
# stype:role, 538: , loss 1.09276, acc 0.95
# stype:event, 539: , loss 1.5135, acc 0.85
# stype:role, 539: , loss 1.09167, acc 0.95
# stype:event, 540: , loss 1.58689, acc 0.8
# stype:role, 540: , loss 1.09644, acc 0.95
# stype:event, 541: , loss 1.56984, acc 0.8
# stype:role, 541: , loss 1.05877, acc 1
# stype:event, 542: , loss 1.56163, acc 0.8
# stype:role, 542: , loss 1.05113, acc 1
# stype:event, 543: , loss 1.51916, acc 0.85
# stype:role, 543: , loss 1.05693, acc 1
# stype:event, 544: , loss 1.3979, acc 1
# stype:role, 544: , loss 1.09549, acc 0.95
# stype:event, 545: , loss 1.45037, acc 0.95
# stype:role, 545: , loss 1.06719, acc 1
# stype:event, 546: , loss 1.53399, acc 0.85
# stype:role, 546: , loss 1.14449, acc 0.9
# stype:event, 547: , loss 1.52857, acc 0.85
# stype:role, 547: , loss 1.14157, acc 0.9
# stype:event, 548: , loss 1.66567, acc 0.7
# stype:role, 548: , loss 1.19429, acc 0.85
# stype:event, 549: , loss 1.5035, acc 0.85
# stype:role, 549: , loss 1.16806, acc 0.85
# stype:event, 550: , loss 1.51926, acc 0.85
# stype:role, 550: , loss 1.16571, acc 0.9
# stype:event, 551: , loss 1.4217, acc 0.95
# stype:role, 551: , loss 1.04406, acc 1
# stype:event, 552: , loss 1.51688, acc 0.85
# stype:role, 552: , loss 1.09539, acc 0.95
# stype:event, 553: , loss 1.56156, acc 0.8
# stype:role, 553: , loss 1.09574, acc 0.95
# stype:event, 554: , loss 1.57826, acc 0.8
# stype:role, 554: , loss 1.09286, acc 0.95
# stype:event, 555: , loss 1.51969, acc 0.85
# stype:role, 555: , loss 1.1267, acc 0.9
# stype:event, 556: , loss 1.5174, acc 0.85
# stype:role, 556: , loss 1.12896, acc 0.9
# stype:event, 557: , loss 1.61586, acc 0.75
# stype:role, 557: , loss 1.14368, acc 0.9
# stype:event, 558: , loss 1.52188, acc 0.85
# stype:role, 558: , loss 1.20425, acc 0.85
# stype:event, 559: , loss 1.47052, acc 0.9
# stype:role, 559: , loss 1.04672, acc 1
# stype:event, 560: , loss 1.51764, acc 0.85
# stype:role, 560: , loss 1.04488, acc 1
# stype:event, 561: , loss 1.52174, acc 0.85
# stype:role, 561: , loss 1.19093, acc 0.85
# stype:event, 562: , loss 1.51883, acc 0.85
# stype:role, 562: , loss 1.09473, acc 0.95
# stype:event, 563: , loss 1.47256, acc 0.9
# stype:role, 563: , loss 1.15753, acc 0.9
# stype:event, 564: , loss 1.46822, acc 0.9
# stype:role, 564: , loss 1.19226, acc 0.85
# stype:event, 565: , loss 1.46993, acc 0.9
# stype:role, 565: , loss 1.09018, acc 0.95
# stype:event, 566: , loss 1.57127, acc 0.8
# stype:role, 566: , loss 1.126, acc 0.9
# stype:event, 567: , loss 1.47034, acc 0.9
# stype:role, 567: , loss 1.0949, acc 0.95
# stype:event, 568: , loss 1.56464, acc 0.8
# stype:role, 568: , loss 1.13898, acc 0.9
# stype:event, 569: , loss 1.46853, acc 0.9
# stype:role, 569: , loss 1.09501, acc 0.95
# stype:event, 570: , loss 1.46966, acc 0.9
# stype:role, 570: , loss 1.10392, acc 0.95
# stype:event, 571: , loss 1.47234, acc 0.9
# stype:role, 571: , loss 1.09713, acc 0.95
# stype:event, 572: , loss 1.37263, acc 1
# stype:role, 572: , loss 1.10371, acc 0.95
# stype:event, 573: , loss 1.57864, acc 0.8
# stype:role, 573: , loss 1.04614, acc 1
# stype:event, 574: , loss 1.52306, acc 0.85
# stype:role, 574: , loss 1.07304, acc 0.95
# stype:event, 575: , loss 1.42263, acc 0.95
# ...
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：中航重机, 、, 银邦股份, 、, 海源机械, 纷纷, 冲击, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机, 中航重机
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：中航重机, 、, 银邦股份, 、, 海源机械, 纷纷, 冲击, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份, 银邦股份
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：中航重机, 、, 银邦股份, 、, 海源机械, 纷纷, 冲击, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械, 海源机械
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：博腾股份, 下跌, 逾, 9%, 。, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌
# 候选词：博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份, 博腾股份
# 预测事件类别:股票降低类事件
# 预测角色类别:施事角色
# 输入数据：博腾股份, 下跌, 逾, 9%, 。, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌
# 候选词：9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%, 9%
# 预测事件类别:股票降低类事件
# 预测角色类别:数字角色
# 输入数据：绿盟科技, 、, 易事特, 下跌, 逾, 7%, 。, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌
# 候选词：绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技, 绿盟科技
# 预测事件类别:股票降低类事件
# 预测角色类别:施事角色
# 输入数据：绿盟科技, 、, 易事特, 下跌, 逾, 7%, 。, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌
# 候选词：易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特, 易事特
# 预测事件类别:股票降低类事件
# 预测角色类别:施事角色
# 输入数据：绿盟科技, 、, 易事特, 下跌, 逾, 7%, 。, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌, 下跌
# 候选词：7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%, 7%
# 预测事件类别:股票降低类事件
# 预测角色类别:数字角色
# 输入数据：登云股份, 、, 天保, 重装, 两股, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份, 登云股份
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：登云股份, 、, 天保, 重装, 两股, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保, 天保
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：中国联通, 盘中, 冲击, 涨停, 也, 有效地, 恢复, 了, 市场, 人气, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通, 中国联通
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：徐家汇, 等, 多, 股, 齐, 飙涨, 停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨, 飙涨
# 候选词：徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：仪电电子, 、, 中国石化, 、, 京东方, 等, 低价, 大盘股, 出现, 异动, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动
# 候选词：仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子, 仪电电子
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：仪电电子, 、, 中国石化, 、, 京东方, 等, 低价, 大盘股, 出现, 异动, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动
# 候选词：中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化, 中国石化
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：仪电电子, 、, 中国石化, 、, 京东方, 等, 低价, 大盘股, 出现, 异动, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动, 异动
# 候选词：京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方, 京东方
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：英飞拓, 、, 蓝盾股份, 盘中, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓, 英飞拓
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：英飞拓, 、, 蓝盾股份, 盘中, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份, 蓝盾股份
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：金一文化, 、, 金轮股份, 等, 16只, 次新股, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化, 金一文化
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：金一文化, 、, 金轮股份, 等, 16只, 次新股, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份, 金轮股份
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：12月20日, 尾盘, 建设银行, (), 等, 大盘, 金融股, 惊, 现, 暴跌, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌
# 候选词：建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行, 建设银行
# 预测事件类别:产品跌价类事件
# 预测角色类别:其它角色
# 输入数据：12月20日, 尾盘, 建设银行, (), 等, 大盘, 金融股, 惊, 现, 暴跌, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌, 暴跌
# 候选词：12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日, 12月20日
# 预测事件类别:股票降低类事件
# 预测角色类别:施事角色
# 输入数据：新世界, 、, 徐家汇, 强势, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇, 徐家汇
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：新世界, 、, 徐家汇, 强势, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界, 新世界
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：自仪股份, 、, 上海九百, 、, 益民集团, 等, 也, 出现, 大幅, 上涨, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨
# 候选词：自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份, 自仪股份
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：自仪股份, 、, 上海九百, 、, 益民集团, 等, 也, 出现, 大幅, 上涨, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨
# 候选词：上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百, 上海九百
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：自仪股份, 、, 上海九百, 、, 益民集团, 等, 也, 出现, 大幅, 上涨, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨
# 候选词：益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团, 益民集团
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：万向钱潮, 一度, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮, 万向钱潮
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：赛为智能, 、, 扬杰科技, 、, 新国都, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能, 赛为智能
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：赛为智能, 、, 扬杰科技, 、, 新国都, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技, 扬杰科技
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：赛为智能, 、, 扬杰科技, 、, 新国都, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都, 新国都
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：新宙邦, 、, 赣锋锂业, 等, 也, 出现, 大幅, 上涨, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨
# 候选词：新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦, 新宙邦
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：新宙邦, 、, 赣锋锂业, 等, 也, 出现, 大幅, 上涨, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨, 上涨
# 候选词：赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业, 赣锋锂业
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
# 输入数据：中邮, 战略, 新兴产业, 一直, 在, 增持, 旋极信息, 、, 汉鼎股份, 以及, 国瓷新材, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持
# 候选词：中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮, 中邮
# 预测事件类别:股票交易类事件
# 预测角色类别:施事角色
# 输入数据：中邮, 战略, 新兴产业, 一直, 在, 增持, 旋极信息, 、, 汉鼎股份, 以及, 国瓷新材, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持
# 候选词：旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息, 旋极信息
# 预测事件类别:股票交易类事件
# 预测角色类别:数字角色
# 输入数据：中邮, 战略, 新兴产业, 一直, 在, 增持, 旋极信息, 、, 汉鼎股份, 以及, 国瓷新材, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持
# 候选词：汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份, 汉鼎股份
# 预测事件类别:股票交易类事件
# 预测角色类别:施事角色
# 输入数据：中邮, 战略, 新兴产业, 一直, 在, 增持, 旋极信息, 、, 汉鼎股份, 以及, 国瓷新材, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持, 增持
# 候选词：国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材, 国瓷新材
# 预测事件类别:股票交易类事件
# 预测角色类别:其它角色
# 输入数据：方正证券, 、, 山西证券, 先后, 封, 上, 涨停, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>, <eos>
# 触发词：涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停, 涨停
# 候选词：方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券, 方正证券
# 预测事件类别:股票增长类事件
# 预测角色类别:施事角色
